# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
load_dotenv()
llm=ChatGoogleGenerativeAI(model="gemma-4-31b-it",api_key="GOOGLE_API_KEY")

# %%
with open("Blood_test_report.txt","r") as f:
          blood_test=f.read()
print(blood_test[:200])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5â€“17.5)
# Hematocrit:        44%

# %%
extraction_prompt = f"""
You are a model dta extraction assistant.

From the Blood report below, extract All test values and classify each one as HIGH, LOW, or NORMAL
based on the reference ranges provided in the report 

Format your response as:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range

Blood Report:
{blood_test}
"""
extraction_response = llm.invoke(extraction_prompt)
extraction_response = extraction_response.text

print("=== STAGE 1: EXTRACTION VALUES ===")
print(extraction_response)
# Out:
# === STAGE 1: EXTRACTION VALUES ===
# - Hemoglobin: 15.1 g/dL | Status: NORMAL | Reference: 13.5–17.5
# - Hematocrit: 44% | Status: NORMAL | Reference: 41–53%
# - WBC: 6.8 x10^3/uL | Status: NORMAL | Reference: 4.5–11.0
# - Platelets: 220 x10^3/uL | Status: NORMAL | Reference: 150–400
# - Total Cholesterol: 238 mg/dL | Status: HIGH | Reference: <200
# - LDL Cholesterol: 162 mg/dL | Status: HIGH | Reference: <100
# - HDL Cholesterol: 36 mg/dL | Status: LOW | Reference: >40
# - Triglycerides: 188 mg/dL | Status: HIGH | Reference: <150
# - Glucose (Fasting): 92 mg/dL | Status: NORMAL | Reference: 70–99
# - HbA1c: 5.3% | Status: NORMAL | Reference: <5.7%
# - Creatinine: 1.0 mg/dL | Status: NORMAL | Reference: 0.7–1.3
# - eGFR: 82 mL/min | Status: NORMAL | Reference: >60
# - ALT: 28 U/L | Status: NORMAL | Reference: 7–40
# - AST: 25 U/L | Status: NORMAL | Reference: 10–40
# - Bilirubin Total: 0.8 mg/dL | Status: NORMAL | Reference: 0.2–1.2

# %% [markdown]
#  # Suggesting the Diet Plan According to the test report

# %%
diet_prompt = f"""
You are a clinical nutritionist specializing the Indian dietry habits.

Based on the blood work analysis below, write:
1. A short health summary in 4-5 lines explaining the patient's condition in simple language 
2. A short, practical Indian diet plan having only two sections (1) Foods to avoid (2) Foods to eat more of

Blood work analysis:
{extraction_response}
"""

diet_response = llm.invoke(diet_prompt)
print("""=== Stage 2: HEALTH SUMMARY & DIET PLAN ===""")
print(diet_response.text)
# Out:
# === Stage 2: HEALTH SUMMARY & DIET PLAN ===
# ***Disclaimer:** I am an AI, not a doctor. Please consult with your primary healthcare provider or a registered dietitian before making significant dietary changes or starting any supplements.*
#
# ### Health Summary
# Your blood work shows that your blood sugar, kidney, and liver functions are all within the healthy range. However, your lipid profile indicates **dyslipidemia**, meaning you have high "bad" cholesterol (LDL) and triglycerides, and low "good" cholesterol (HDL). This combination can increase the risk of plaque buildup in your arteries. The primary goal now is to lower these fat levels through heart-healthy dietary choices and physical activity.
#
# ---
#
# ### Practical Indian Diet Plan
#
# #### ❌ Foods to Avoid (or Limit Strictly)
# *   **Fried Snacks:** Samosas, pakoras, puri, bhujia, and papad.
# *   **Refined Carbohydrates:** Maida (white flour), white bread, biscuits, and white rice (limit portions).
# *   **Saturated & Trans Fats:** Vanaspati, palm oil, excessive ghee, butter, and full-fat cream.
# *   **Sugary Treats:** Mithai, sugary tea/coffee, soft drinks, and processed jams.
# *   **High-Fat Dairy:** Full-cream milk and processed cheese.
#
# #### ✅ Foods to Eat More Of
# *   **Whole Grains & Millets:** Replace white rice/maida with Oats, Dalia (broken wheat), Jowar, Bajra, Ragi, and brown or red rice.
# *   **Fiber-Rich Legumes:** Moong dal, masoor dal, chickpeas (chole), and kidney beans (rajma)—preferably boiled or steamed rather than fried.
# *   **Heart-Healthy Fats:** Walnuts, almonds, flaxseeds, and chia seeds. Use mustard oil, olive oil, or rice bran oil in small quantities.
# *   **Vegetables & Fruits:** Increase intake of green leafy vegetables, okra (bhindi), eggplant (baingan), apples, papaya, and citrus fruits.
# *   **Omega-3 Sources:** If non-vegetarian, include grilled or steamed fish (like Rohu or Mackerel); if vegetarian, focus on flaxseed powder and walnuts.
